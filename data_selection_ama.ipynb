# %%
pip install webdriver-manager
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: webdriver-manager in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.0.2)
# Requirement already satisfied: requests in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from webdriver-manager) (1.1.0)
# Requirement already satisfied: packaging in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from webdriver-manager) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->webdriver-manager) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->webdriver-manager) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->webdriver-manager) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->webdriver-manager) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\pitsc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.32.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.4.0)
# Requirement already satisfied: trio~=0.17 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from selenium) (2025.4.26)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trio~=0.17->selenium) (3.10)
# Requirement already satisfied: outcome in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trio~=0.17->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.22)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\pitsc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install chromedriver_autoinstaller
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: chromedriver_autoinstaller in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.6.4)
# Requirement already satisfied: packaging>=23.1 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from chromedriver_autoinstaller) (24.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\pitsc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2025.4.26)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\pitsc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install beautifulsoup4
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulsoup4 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from beautifulsoup4) (4.13.2)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\pitsc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\pitsc\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\pitsc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from scraper_selenium import selenium_scraper
from bs4 import BeautifulSoup
import pandas as pd
from clean_price import clean_price
from IPython.display import display

# %%
soup = selenium_scraper("https://www.americanas.com.br/s?q=iphone+16&fuzzy=0&operator=and&facets=fuzzy%2Coperator&sort=score_desc&page=0")

# %%
print(soup.prettify())
# Out:
# <html lang="pt-BR">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <title>
#    iphone 16: Promoção | Americanas
#   </title>
#   <meta content="index,follow" name="robots"/>
#   <meta content="iphone 16" property="og:title"/>
#   <meta content="iphone 16 em promoção que você procura? Na Americanas você encontra as melhores ofertas de produtos com entrega rápida. Vem!" property="og:description"/>
#   <meta content="https://www.americanas.com.br/s?q=iphone+16" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <link href="https://www.americanas.com.br/s?q=iphone+16" rel="canonical"/>
#   <meta content="2025-05-19T12:15:09.285Z" name="generated-at"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/storeLogoIcon.0f542fa4.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/storeFrontIcon.759623b8.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/storeWhishListIcon.0ddddf87.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/storeCartIcon.46c2c513.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/storeRegionIcon.aaf1e87a.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/storeLinkIcon.7f5bb130.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/greyHamburguerIcon.54572277.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/greyArrowDownIcon.80ce865c.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/storeLoginIcon.0af75623.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/modalCloseIcon.8bacd3b4.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/linkIcon.dbb70f32.svg" rel="preload"/>
#   <meta content="iphone 16: Promoção | Americanas" property="og:title"/>
#   <meta content="iphone 16: em promoção que você procura? Na Americanas você encontra as melhores ofertas de produtos com entrega rápida. Vem!" property="og:description"/>
#   <link href="https://www.americanas.com.br/s?_q=iphone+16" rel="canonical"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/filterIcon.a83b0c9d.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/gridActiveIcon.3f5bc6f4.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/listInactiveIcon.6e9744d5.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/arrowDownIcon.1e927531.svg" rel="preload"/>
#   <meta content="iphone 16: em promoção que você procura? Na Americanas você encontra as melhores ofertas de produtos com entrega rápida. Vem!" name="description"/>
#   <link href="https://www.americanas.com.br/s?q=iphone+16&amp;fuzzy=0&amp;operator=and&amp;facets=fuzzy%2Coperator&amp;sort=score_desc&amp;page=1" rel="next"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/seloProconIcon.855d98cc.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/logoFooterDesktopIcon.0204a0de.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/chevronDownIcon.c60d0467.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/instagramIcon.d3309b6e.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/youtubeIcon.41f0f8eb.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/facebookIcon.86d8823e.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/tiktokIcon.be2f67cf.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/arrowLeftIcon.ce72092a.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/arrowLeftIcon.ce72092a.svg" rel="preload"/>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.americanas.com.br/caixa-de-bombom-garoto-250g-1417116092/p?idsku=3952806","name":"Caixa de Bombom Garoto 250g","brand":"Desconhecida","productId":"3709719","offers":{"@type":"Offer","price":13.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":2,"url":"https://www.americanas.com.br/chocolate-kit-kat-ao-leite-nestle-41-5g-44414152/p?idsku=3990134","name":"Chocolate Kit Kat ao Leite Nestlé - 41,5g","brand":"Desconhecida","productId":"3742575","offers":{"@type":"Offer","price":3.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":3,"url":"https://www.americanas.com.br/caixa-bombom-especialidades-nestle-251g-1673764005/p?idsku=6546511","name":"Caixa Bombom Especialidades Nestlé 251g","brand":"Desconhecida","productId":"6140062","offers":{"@type":"Offer","price":14.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":4,"url":"https://www.americanas.com.br/barra-de-chocolate-branco-lacta-com-recheio-ouro-branco-98g-7461809591/p?idsku=602345","name":"Barra de Chocolate Branco Lacta com Recheio Ouro Branco 98g","brand":"Desconhecida","productId":"566112","offers":{"@type":"Offer","price":7.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":5,"url":"https://www.americanas.com.br/barra-de-chocolate-alpino-nestle-85g-6164790774/p?idsku=3087000","name":"Barra de Chocolate Alpino  Nestlé - 85g","brand":"Desconhecida","productId":"2897602","offers":{"@type":"Offer","price":7.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":6,"url":"https://www.americanas.com.br/barra-de-chocolate-ao-leite-lacta-com-recheio-sonho-de-valsa-98g-7460952826/p?idsku=3512415","name":"Barra de Chocolate ao Leite Lacta com Recheio Sonho de Valsa 98g","brand":"Desconhecida","productId":"3296665","offers":{"@type":"Offer","price":7.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":7,"url":"https://www.americanas.com.br/barra-de-chocolate-lacta-ao-leite-80g-6331301511/p?idsku=1976338","name":"Barra de Chocolate Lacta ao Leite 80g","brand":"Desconhecida","productId":"1855837","offers":{"@type":"Offer","price":7.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":8,"url":"https://www.americanas.com.br/barra-de-chocolate-ao-leite-diamante-negro-80g-6331286592/p?idsku=4001085","name":"Barra de Chocolate ao Leite Diamante Negro 80g","brand":"Desconhecida","productId":"3752529","offers":{"@type":"Offer","price":7.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":9,"url":"https://www.americanas.com.br/barra-de-chocolate-branco-laka-oreo-80g-6331291033/p?idsku=4001137","name":"Barra de Chocolate Branco Laka Oreo 80g","brand":"Desconhecida","productId":"3752561","offers":{"@type":"Offer","price":7.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":10,"url":"https://www.americanas.com.br/barra-de-chocolate-branco-laka-80g-6331298198/p?idsku=2283646","name":"Barra de Chocolate Branco Laka 80g","brand":"Desconhecida","productId":"2143963","offers":{"@type":"Offer","price":7.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}}]}
#   </script>
#   <link as="image" fetchpriority="high" href="/_next/static/media/arrowLeftIcon.ce72092a.svg" rel="preload"/>
#   <link as="image" fetchpriority="high" href="/_next/static/media/arrowLeftIcon.ce72092a.svg" rel="preload"/>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.americanas.com.br/ovo-de-pascoa-playstation-chocolate-ao-leite-90g-topcau-7515087252/p","name":"Ovo de Páscoa Playstation Chocolate ao Leite 90g - Topcau","brand":"Topcau","productId":"7501750","offers":{"@type":"Offer","price":64.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":2,"url":"https://www.americanas.com.br/ovo-de-pascoa-chocolate-ao-leite-manchester-city-topcau-120g-vem-com-uma-bola-exclusiva-7514017136/p","name":"Ovo de Páscoa Manchester City Chocolate ao Leite Topcau 120g Vem com uma Bola Exclusiva","brand":"Topcau","productId":"7501741","offers":{"@type":"Offer","price":159.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":3,"url":"https://www.americanas.com.br/ovo-pascoa-lol-omg-80g-top-cau-7516298072/p","name":"Ovo de Páscoa LOL OMG Chocolate ao Leite 80g - Topcau","brand":"Não Disponível","productId":"7501092","offers":{"@type":"Offer","price":25.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":4,"url":"https://www.americanas.com.br/ovo-de-pascoa-chocolate-ao-leite-bluey-80g-topcau-7516265215/p","name":"Ovo de Páscoa Chocolate ao Leite Bluey 80g - Topcau","brand":"Topcau","productId":"7500796","offers":{"@type":"Offer","price":25.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":5,"url":"https://www.americanas.com.br/ovo-pascoa-ben-10-80g-top-cau-7516325156/p","name":"Ovo de Páscoa Ben 10 Chocolate ao Leite 80g - Topcau","brand":"Não Disponível","productId":"7501089","offers":{"@type":"Offer","price":25.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":6,"url":"https://www.americanas.com.br/ovo-pascoa-lol-omg-90g-top-cau-7516308628/p","name":"Ovo de Páscoa LOL Chocolate ao Leite 90g - Delice","brand":"Não Disponível","productId":"7501747","offers":{"@type":"Offer","price":64.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":7,"url":"https://www.americanas.com.br/ovo-de-pascoa-chocolate-ao-leite-clube-de-regatas-do-flamengo-topcau-120g-vem-com-uma-bola-exclusiva-7514017140/p","name":"Ovo de Páscoa Flamengo Chocolate ao Leite Topcau 120g Vem com uma Bola Exclusiva","brand":"Topcau","productId":"7501751","offers":{"@type":"Offer","price":159.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":8,"url":"https://www.americanas.com.br/ovo-de-pascoa-chocolate-ao-leite-ben-10-90g-topcau-7515073850/p","name":"Ovo de Páscoa Chocolate ao Leite Ben 10 90g - Topcau","brand":"Topcau","productId":"7501752","offers":{"@type":"Offer","price":64.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":9,"url":"https://www.americanas.com.br/ovo-de-pascoa-crocante-chocolate-ao-leite-120g-topcau-7515087247/p","name":"Ovo de Páscoa Crocante Chocolate ao Leite 120g - Topcau","brand":"Topcau","productId":"7500810","offers":{"@type":"Offer","price":32.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":10,"url":"https://www.americanas.com.br/ovo-de-pascoa-bluey-chocolate-ao-leite-90g-topcau-7515087251/p","name":"Ovo de Páscoa Bluey Chocolate ao Leite 90g - Topcau","brand":"Topcau","productId":"7501740","offers":{"@type":"Offer","price":64.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":11,"url":"https://www.americanas.com.br/chocolate-bis-lacta-xtra-45g-1760602506/p","name":"Chocolate Bis Lacta Xtra 45g","brand":"Lacta","productId":"1617735","offers":{"@type":"Offer","price":3.99,"priceCurrency":"BRL","availability":"https://schema.org/InStock"}},{"@type":"ListItem","position":12,"url":"https://www.americanas ...
#   </script>
#   <meta content="43" name="next-head-count"/>
#   <link href="https://americanas.vtexassets.com" rel="preconnect"/>
#   <link href="https://americanas.vtexassets.com" rel="dns-prefetch"/>
#   <meta content="fast_store" name="storefront"/>
#   <script async="" src="https://analytics.tiktok.com/i18n/pixel/static/identify_935b0d03.js" type="text/javascript">
#   </script>
#   <script async="" data-id="CUVLSTJC77U2F130TOJG" src="https://analytics.tiktok.com/i18n/pixel/static/main.MWNiZTQ2MTFhMQ.js" type="text/javascript">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/1177741787354858?v=2.9.202&amp;r=stable&amp;domain=www.americanas.com.br&amp;hme=1176bfe419ac27e059a43d3ca1b7b749889cd7631eab574b2b915396f4ce500a&amp;ex_m=74%2C129%2C114%2C118%2C65%2C6%2C107%2C73%2C19%2C101%2C93%2C55%2C58%2C184%2C205%2C212%2C208%2C209%2C211%2C32%2C108%2C57%2C81%2C210%2C179%2C182%2C206%2C207%2C192%2C141%2C45%2C197%2C194%2C195%2C37%2C153%2C18%2C54%2C201%2C200%2C143%2C21%2C44%2C2%2C47%2C69%2C70%2C71%2C75%2C97%2C20%2C17%2C100%2C96%2C95%2C115%2C56%2C117%2C42%2C116%2C33%2C98%2C43%2C90%2C29%2C180%2C183%2C150%2C14%2C15%2C16%2C8%2C9%2C28%2C25%2C26%2C61%2C66%2C68%2C79%2C106%2C109%2C30%2C80%2C12%2C10%2C84%2C52%2C24%2C111%2C110%2C112%2C103%2C13%2C23%2C4%2C41%2C78%2C22%2C162%2C137%2C77%2C1%2C99%2C60%2C88%2C36%2C31%2C86%2C87%2C92%2C40%2C7%2C94%2C85%2C48%2C35%2C38%2C0%2C72%2C119%2C91%2C5%2C51%2C50%2C102%2C89%2C249%2C177%2C127%2C165%2C158%2C3%2C39%2C67%2C46%2C113%2C49%2C83%2C64%2C63%2C34%2C104%2C62%2C59%2C53%2C82%2C76%2C27%2C105%2C11%2C120">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script async="" src="https://analytics.tiktok.com/i18n/pixel/events.js?sdkid=CUVLSTJC77U2F130TOJG&amp;lib=ttq" type="text/javascript">
#   </script>
#   <script async="" src="https://dynamic.criteo.com/js/ld/ld.js?a=8416" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=DC-4945378&amp;cx=c&amp;gtm=45He55g2v9207098768za200&amp;tag_exp=101509157~103116025~103130495~103130497~103136993~103136995~103200001~103207802~103233427~103252644~103252646~103263073~103301114~103301116" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1039881882&amp;cx=c&amp;gtm=45He55g2v9207098768za200&amp;tag_exp=101509157~103116025~103130495~103130497~103136993~103136995~103200001~103207802~103233427~103252644~103252646~103263073~103301114~103301116" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-6S3127E82D&amp;cx=c&amp;gtm=45He55g2v9207098768za200&amp;tag_exp=101509157~103116025~103130495~103130497~103136993~103136995~103200001~103207802~103233427~103252644~103252646~103263073~103301114~103301116" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5TPDVK2Z">
#   </script>
#   <script async="" src="https://activity-flow.vtex.com/af/af.js">
#   </script>
#   <script>
#    var partytown={forward:[...["sendrc"],!window.location.search.includes('gtm_debug=')&&false?'dataLayer.push':null].filter(Boolean)}
#   </script>
#   <script type="text/partytown-x">
#    window.VTEX_METADATA = {account:'americanas', renderer: 'faststore'};
#             window.sendrc=function(en,ed){window.NavigationCapture&&window.NavigationCapture.sendEvent(en,ed)};
#   </script>
#   <script async="" src="https://io.vtex.com.br/rc/rc.js" type="text/partytown-x">
#   </script>
#   <script type="text/javascript">
#    (function(v,t,e,x,a,f,s){
#               f=v.vtexaf=v.vtexaf||function(){(f.q=f.q||[]).push(arguments)}
#               ;f.l=+new Date;s=t.createElement(e);s.async=!0;
#               s.src=x;a=t.getElementsByTagName(e)[0];
#               a.parentNode.insertBefore(s,a)
#             })(window,document,'script','https://activity-flow.vtex.com/af/af.js');
#   </script>
#   <script type="text/javascript">
#    window.vtexaf('init', {
#               account: 'americanas',
#               env: 'vtexcommercestable',
#               workspace: 'master'
#             });
#   </script>
#   <script async="">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-5TPDVK2Z');
#   </script>
#   <link href="https://cdn.privacytools.com.br/public_api/banner/style/xz1N21419101.css?t=1" rel="stylesheet"/>
#   <script src="https://cdn.privacytools.com.br/public_api/banner/script/bottom/xz1N21419101.js?t=1" type="text/javascript">
#   </script>
#   <meta content="9BlvZkcfeD56_XPs9GeY7fZaDxy2tXm_v4eQkv0zI6Q" name="google-site-verification"/>
#   <script data-partytown="">
#    !(function(w,p,f,c){c=w[p]=w[p]||{};c[f]=(c[f]||[])})(window,'partytown','forward');/* Partytown 0.6.4 - MIT builder.io */
# !function(t,e,n,i,r,o,a,d,s,c,p,l){function u(){l||(l=1,"/"==(a=(o.lib||"/~partytown/")+(o.debug?"debug/":""))[0]&&(s=e.querySelectorAll('script[type="text/partytown"]'),i!=t?i.dispatchEvent(new CustomEvent("pt1",{detail:t})):(d=setTimeout(w,1e4),e.addEventListener("pt0",f),r?h(1):n.serviceWorker?n.serviceWorker.register(a+(o.swPath||"partytown-sw.js"),{scope:a}).then((function(t){t.active?h():t.installing&&t.installing.addEventListener("statechange",(function(t){"activated"==t.target.state&&h()}))}),console.error):w())))}function h(t){c=e.createElement(t?"script":"iframe"),t||(c.setAttribute("style","display:block;width:0;height:0;border:0;visibility:hidden"),c.setAttribute("aria-hidden",!0)),c.src=a+"partytown-"+(t?"atomics.js?v=0.6.4":"sandbox-sw.html?"+Date.now()),e.body.appendChild(c)}function w(t,n){for(f(),t=0;t<s.length;t++)(n=e.createElement("script")).innerHTML=s[t].innerHTML,e.head.appendChild(n);c&&c.parentNode.removeChild(c)}function f(){clearTimeout(d)}o=t.partytown||{},i==t&&(o.forward||[]).map((function(e){p=t,e.split(".").map((function(e,n,i){p=p[i[n]]=n+1<i.length?"push"==i[n+1]?[]:p[i[n]]||{}:function(){(t._ptf=t._ptf||[]).push(i,arguments)}}))})),"complete"==e.readyState?u():(t.addEventListener("DOMContentLoaded",u),t.addEventListener("load",u))}(window,document,navigator,top,window.crossOriginIsolated);document.currentScript.dataset.partytown="";
#   </script>
#   <link href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com/css2?family=Bungee+Spice&amp;family=Roboto+Flex:opsz,wght@8..144,100..1000&amp;display=swap" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:ital,wght@0,100;0,300;0,400;0,500;0,700;0,900;1,100;1,300;1,400;1,500;1,700;1,900&amp;display=swap" rel="stylesheet"/>
#   <link as="style" href="/_next/static/css/04bf207674f55cf6.css" rel="preload"/>
#   <link data-n-g="" href="/_next/static/css/04bf207674f55cf6.css" rel="stylesheet"/>
#   <link as="style" href="/_next/static/css/90a338514a278492.css" rel="preload"/>
#   <link data-n-p="" href="/_next/static/css/90a338514a278492.css" rel="stylesheet"/>
#   <link as="style" href="/_next/static/css/00f986e5993aa817.css" rel="preload"/>
#   <link data-n-p="" href="/_next/static/css/00f986e5993aa817.css" rel="stylesheet"/>
#   <link as="style" href="/_next/static/css/0f1cca38c6e8e2cb.css" rel="preload"/>
#   <link data-n-p="" href="/_next/static/css/0f1cca38c6e8e2cb.css" rel="stylesheet"/>
#   <link as="style" href="/_next/static/css/2980acad3f8e1028.css" rel="preload"/>
#   <link data-n-p="" href="/_next/static/css/2980acad3f8e1028.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/webpack-1081f1b3966fecd2.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/main-104f8ab9745a6733.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/_app-32e0f336b87c87a6.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/c78d26b1-fe043233b220ebfb.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/8586-2aef6fcd2550c520.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/6407-c014084568628efa.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/3105-29ad36b2a0017a04.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/s-e474017f611b7a1d.js">
#   </script>
#   <script defer="" src="/_next/static/yO02BSj-Tso851-sGazWe/_buildManifest.js">
#   </script>
#   <script defer="" src="/_next/static/yO02BSj-Tso851-sGazWe/_ssgManifest.js">
#   </script>
#   <link href="/_next/static/css/6e9b83ba680dd4a6.css" rel="stylesheet" type="text/css"/>
#   <style>
#    .lds-ring[data-v-35b8be05] {
#   display: inline-block;
#   position: relative;
#   width: 16px;
#   height: 16px;
# }
# .lds-ring div[data-v-35b8be05] {
#   box-sizing: border-box;
#   display: block;
#   position: absolute;
#   width: 16px;
#   height: 16px;
#   margin: 3px;
#   border: 3px solid var(--primary-color);
#   border-radius: 50%;
#   animation: lds-ring-35b8be05 1.2s cubic-bezier(0.5, 0, 0.5, 1) infinite;
#   border-color: var(--primary-color) transparent transparent transparent;
# }
# .lds-ring.inverse div[data-v-35b8be05] {
#   border: 3px solid #fff;
#   border-color: #fff transparent transparent transparent;
# }
# .lds-ring div[data-v-35b8be05]:nth-child(1) {
#   animation-delay: -0.45s;
# }
# .lds-ring div[data-v-35b8be05]:nth-child(2) {
#   animation-delay: -0.3s;
# }
# .lds-ring div[data-v-35b8be05]:nth-child(3) {
#   animation-delay: -0.15s;
# }
# @keyframes lds-ring-35b8be05 {
# 0% {
#     transform: rotate(0deg);
# }
# 100% {
#     transform: rotate(360deg);
# }
# }
#   </style>
#   <style>
#   </style>
#   <style>
#    .overlay[data-v-b7eac6ec] {
#     background: rgba(0, 0, 0, 0.4);
#     position: absolute;
#     top: 0;
#     left: 0;
#     right: 0;
#     bottom: 0;
#     content: '';
#     z-index: 999;
# }
# .modal-login[data-v-b7eac6ec] {
#     position: fixed;
#     width: 400px;
#     background: #fff;
#     z-index: 10000;
#     left: 50%;
#     top: 50%;
#     transform: translate(-50%, -50%);
#     box-sizing: border-box;
#     padding: 20px;
#     box-shadow: 0 3px 9px rgb(0 0 0 / 50%);
#     border: 1px solid #999;
# }
# .btn-close[data-v-b7eac6ec] {
#     font-size: 14px;
#     background: transparent;
#     border: none;
#     opacity: 0.2;
#     color: #000;
#     position: absolute;
#     right: 10px;
#     top: 10px;
# }
# h2[data-v-b7eac6ec] {
#     font-size: 22px;
#     text-align: center;
#     margin-top: 0;
# }
# input[type=text][data-v-b7eac6ec],
# input[type=password][data-v-b7eac6ec] {
#     border: 1px solid #BDBDBD;
#     width: 100%;
#     padding: 5px;
#     margin: 0;
# }
# label[data-v-b7eac6ec],
# input[data-v-b7eac6ec] {
#     display: block;
#     margin-top: 20px;
# }
# .btn-link[data-v-b7eac6ec] {
#     color: #777;
#     font-size: 11px;
#     text-transform: none;
#     text-decoration: underline;
#     margin-bottom: 10px;
# }
# .btn-login + h2[data-v-b7eac6ec] {
#     margin-top: 30px;
# }
#   </style>
#   <style>
#    .stars[data-v-1e309ef8] {
#         margin-top: 10px;
#     display: inline-block;
#     vertical-align: middle;
# }
# button.star[data-v-1e309ef8] {
#     background: 0 0;
#     border: none;
#     padding: 0;
#     min-width: unset!important;
#     background: transparent!important;
#     box-shadow: none!important;
# }
# .star img[data-v-1e309ef8] {
#     height: 35px;
#     filter: grayscale(1)
# }
# .star.active img[data-v-1e309ef8] {
#     filter: none;
# }
# .rating[data-v-1e309ef8] {
#     display: inline-block;
#     vertical-align: middle;
#     margin-left: 10px;
# }
#   </style>
#   <style>
#    .starsV2 .star[data-v-1e309ef8], .starsV2 .star.fill[data-v-1e309ef8], .starsV2 .star.half[data-v-1e309ef8] {
#   background-size: contain;
# }
#   </style>
#   <style>
#    .lds-ripple[data-v-2c418aa1] {
#     display: inline-block;
#     position: relative;
#     width: 50px;
#     height: 50px;
# }
# .lds-ripple div[data-v-2c418aa1] {
#     position: absolute;
#     border: 4px solid #ccc;
#     opacity: 1;
#     border-radius: 50%;
#     animation: lds-ripple-2c418aa1 1s cubic-bezier(0, 0.2, 0.8, 1) infinite;
# }
# .lds-ripple div[data-v-2c418aa1]:nth-child(2) {
#     animation-delay: -0.5s;
# }
# @keyframes lds-ripple-2c418aa1 {
# 0% {
#       top: 23px;
#       left: 23px;
#       width: 0;
#       height: 0;
#       opacity: 0;
# }
# 4.9% {
#       top: 23px;
#       left: 23px;
#       width: 0;
#       height: 0;
#       opacity: 0;
# }
# 5% {
#       top: 23px;
#       left: 23px;
#       width: 0;
#       height: 0;
#       opacity: 1;
# }
# 100% {
#       top: 0px;
#       left: 0px;
#       width: 45px;
#       height: 45px;
#       opacity: 0;
# }
# }
#   </style>
#   <style>
#    .overlay[data-v-6dedc520] {
#   background: rgba(0, 0, 0, 0.4);
#   position: fixed;
#   top: 0;
#   left: 0;
#   right: 0;
#   bottom: 0;
#   content: '';
#   z-index: 999;
#   display: block;
# }
# .modal-review[data-v-6dedc520] {
#   position: fixed;
#   width: 400px;
#   background: #fff;
#   z-index: 10000;
#   left: 50%;
#   top: 50%;
#   transform: translate(-50%, -50%);
#   box-sizing: border-box;
#   padding: 20px;
#   box-shadow: 0 3px 9px rgb(0 0 0 / 50%);
#   border: 1px solid #999;
#   max-height: 100vh;
#   overflow-y: auto;
# }
# .btn-close[data-v-6dedc520] {
#   font-size: 20px;
#   font-weight: bold;
#   background: transparent;
#   border: none;
#   opacity: 0.2;
#   color: #000;
#   position: absolute;
#   right: 10px;
#   top: 10px;
#   min-width: unset;
# }
# .btn-close[data-v-6dedc520]:hover {
#   background: transparent;
#   min-width: unset;
#   box-shadow: none;
# }
# h2[data-v-6dedc520] {
#   font-size: 22px;
#   text-align: center;
#   margin-top: 0;
# }
# .tip[data-v-6dedc520] {
#   font-weight: normal;
#   font-size: 11px;
#   color: #777;
# }
# label[data-v-6dedc520] {
#   display: block;
#   margin-top: 10px;
# }
# label input[type='radio'][data-v-6dedc520] {
#   apperance: auto;
#   -webkit-appearance: auto;
# }
# label.option[data-v-6dedc520] {
#   display: inline-block;
#   font-weight: normal;
#   margin-bottom: 15px;
#   margin-top: 0;
# }
# label.option + label.option[data-v-6dedc520] {
#   margin-left: 20px;
# }
# input.personal-data[data-v-6dedc520] {
#   border: 1px solid #cdcdcd;
#   border-radius: 5px;
#   width: 100%;
#   box-sizing: border-box;
#   padding: 10px;
#   min-height: 35px;
#   margin: 0;
# }
# ul[data-v-6dedc520] {
#   list-style: none;
#   margin: 20px 0 0 0;
#   padding: 0;
# }
# ul li[data-v-6dedc520] {
#   margin: 0;
#   padding: 0;
#   display: inline-block;
#   position: relative;
#   vertical-align: top;
#   margin-right: 15px;
#   margin-bottom: 15px;
#   border: 2px solid #d8d8d8;
#   border-radius: 6px;
#   width: 60px;
#   height: 60px;
#   box-sizing: content-box;
# }
# ul li img[data-v-6dedc520] {
#   width: 60px;
#   height: 60px;
#   object-fit: cover;
#   border-radius: 5px;
# }
# #review-video[data-v-6dedc520] {
#   width: 60px;
#   height: 60px;
# }
# ul li span[data-v-6dedc520] {
#   position: absolute;
#   top: -10px;
#   right: -10px;
#   z-index: 999;
#   border-radius: 10px;
#   background: #999;
#   width: 20px;
#   height: 20px;
#   text-align: center;
#   color: #fff;
#   font-size: 12px;
#   line-height: 18px;
#   font-weight: bold;
#   cursor: pointer;
# }
# .add[data-v-6dedc520] {
#   border: 2px dashed #d8d8d8;
# }
# .add button[data-v-6dedc520] {
#   width: 60px;
#   height: 60px;
#   border: none;
#   appearance: none;
#   padding: 0;
#   margin: 0;
#   border-radius: 5px;
#   background: url(https://reviews.konfidency.com.br/americanas/b02bf8ce7b715cebfdce.png) no-repeat center center #f7f7f7;
#   background-size: 30%;
# }
# .actions input[type='file'][data-v-6dedc520] {
#   display: none;
# }
# .actions button[data-v-6dedc520] {
#   float: right;
#   margin-top: 15px;
#   background: var(--primary-color);
#   color: #fff;
#   border: none;
#   padding: 10px 30px;
#   border-radius: 5px;
#   cursor: pointer;
#   line-height: unset;
# }
# .actions button[type='button'][data-v-6dedc520] {
#   float: none;
#   background-color: #fff;
#   color: #999;
#   border: 1px solid #999;
#   background-image: url(https://reviews.konfidency.com.br/americanas/457247f8ec3780661c49.png);
#   background-repeat: no-repeat;
#   background-position: 20px 5px;
#   background-size: 26px;
#   padding: 10px 22px 10px 60px;
# }
# .actions button img[data-v-6dedc520] {
#   vertical-align: top;
#   margin-left: 5px;
# }
# .actions button[disabled][data-v-6dedc520] {
#   opacity: 0.5;
# }
# .error-message[data-v-6dedc520] {
#   margin-top: 15px;
#   color: #ce4747;
#   text-align: center;
# }
# .review-success[data-v-6dedc520] {
#   text-align: center;
# }
# .review-success .success-message[data-v-6dedc520] {
#   display: flex;
#   text-align: left;
#   margin-bottom: 10px;
#   background: transparent;
#   color: unset;
# }
# .review-success .check[data-v-6dedc520] {
#   background: url(https://reviews.konfidency.com.br/americanas/27aedf084252710b5958.png);
#   min-width: 60px;
#   background-size: contain;
#   background-repeat: no-repeat;
#   margin-right: 15px;
# }
# .review-success .message[data-v-6dedc520] {
#   vertical-align: top;
#   display: inline-block;
#   background: transparent;
#   color: unset;
#   margin: unset;
# }
# .review-success .message h3[data-v-6dedc520] {
#   margin-top: 0;
#   margin-bottom: 5px;
# }
# .review-success .error[data-v-6dedc520] {
#   background: url(https://reviews.konfidency.com.br/americanas/13ceff4af424031afb4b.png);
#   width: 80px;
#   height: 80px;
#   background-size: cover;
#   margin: 40px auto;
# }
# .review-success .attributes label[data-v-6dedc520] {
#   text-align: left;
#   margin-top: 20px;
#   margin-bottom: 20px;
#   display: block;
#   font-weight: bold;
# }
# .review-success .attribute[data-v-6dedc520] {
#   text-align: left;
#   margin-bottom: 15px;
# }
# .review-success .attribute select[data-v-6dedc520] {
#   padding: 5px 10px;
#   border-radius: 6px;
#   margin-top: 10px;
# }
# .review-success button[data-v-6dedc520] {
#   border: 1px solid var(--primary-color);
#   border-radius: 5px;
#   background: #fff;
#   font-size: 16px;
#   text-transform: uppercase;
#   color: var(--primary-color);
#   padding: 10px 20px;
#   font-size: 14px;
#   margin-bottom: 10px;
#   font-weight: 500;
#   line-height: unset;
# }
# .review-success .attributes button[type='submit'][data-v-6dedc520] {
#   color: #fff;
#   background-color: var(--primary-color);
# }
# .loading-icon[data-v-6dedc520] {
#   position: absolute;
#   right: 10px;
#   bottom: 10px;
# }
# .completeness[data-v-6dedc520] {
#   background-color: #fdfdfd;
#   border-top: 1px solid #d9d9d9;
#   border-radius: 0 0 5px 5px;
# }
# .completeness .completeness-label[data-v-6dedc520] {
#   font-size: 11px;
#   padding: 10px 10px 0 10px;
# }
# .completeness .completeness-topics[data-v-6dedc520] {
#   display: flex;
#   width: 100%;
# }
# .completeness .completeness-topic[data-v-6dedc520] {
#   flex: 1;
#   padding: 10px 10px 10px 40px;
#   font-size: 14px;
#   text-transform: lowercase;
#   background: url(https://reviews.konfidency.com.br/americanas/5b92e6d0e6036f177826.png) no-repeat;
#   background-position: 20px 14px;
#   background-size: 12px;
#   transition: all 1s ease-in-out;
# }
# .completeness .completeness-topic.complete[data-v-6dedc520] {
#   color: #009c39;
#   font-weight: bold;
#   animation: complete-topic-6dedc520 1s ease-in-out;
#
#   background: url(https://reviews.konfidency.com.br/americanas/35802bf0ca01f41f180c.png) no-repeat;
#   background-position: 20px 14px;
#   background-size: 12px;
# }
# .completeness .completeness-progress[data-v-6dedc520] {
#   background-color: #d8d8d8;
#   border-radius: 0px 0px 4px 4px;
#   width: 100%;
#   height: 10px;
# }
# .completeness .completeness-progress .indicator[data-v-6dedc520] {
#   background-color: #009c39;
#   height: 10px;
#   transition: width 2s ease-in-out;
#   border-radius: 0 0 0 4px;
# }
# .completeness .completeness-progress .indicator.complete[data-v-6dedc520] {
#   border-radius: 0 0 4px 4px;
# }
# .text-container[data-v-6dedc520] {
#   border: 1px solid #cdcdcd;
#   border-radius: 5px;
#   margin-top: 10px;
#   position: relative;
# }
# textarea[data-v-6dedc520] {
#   border: none;
#   border-radius: 5px;
#   width: 100%;
#   display: block;
#   height: 70px;
#   box-sizing: border-box;
#   padding: 10px;
#   font-family: Lato;
#   font-size: 14px;
#   resize: none;
# }
# @keyframes complete-topic-6dedc520 {
# 0% {
#     text-shadow: 0px 0px 16px rgba(0, 156, 57, 0);
# }
# 50% {
#     text-shadow: 0px 0px 16px #009c39;
# }
# 95% {
#     text-shadow: 0px 0px 16px #009c39;
# }
# 100% {
#     text-shadow: 0px 0px 16px rgba(0, 156, 57, 0);
# }
# }
# @media screen and (max-width: 767px) {
# .modal-review[data-v-6dedc520] {
#     box-sizing: border-box;
#     left: 2px;
#     top: 2px;
#     bottom: 2px;
#     right: 2px;
#     position: fixed;
#     width: unset;
#     transform: none;
#     max-width: 100%;
#     font-size: 14px;
# }
# .modal-review .actions button[data-v-6dedc520] {
#     width: 100%;
# }
# .modal-review .actions button[type='button'][data-v-6dedc520] {
#     background-position: calc(50% - 60px);
# }
# }
#   </style>
#   <style>
#    .modal-review[data-v-6dedc520] {
#   font-size: 14px;
#   border-radius: 10px;
# }
# label.text[data-v-6dedc520], label.name[data-v-6dedc520], label.email[data-v-6dedc520] {
#   display: none;
# }
# textarea[data-v-6dedc520] {
#   border: 1px solid #ccc;
# }
# @media screen and (max-width: 767px) {
# .modal-review[data-v-6dedc520] {
#     left: unset;
#     top: 50%;
#     bottom: unset;
#     right: unset;
#     width: 90%;
#     left: 5%;
#     transform: translateY(-50%);
# }
# }
# input[type=text][data-v-6dedc520] {
#   margin-top: 10px!important;
# }
# input[type=radio][data-v-6dedc520] {
#   display: inline-block!important;
#   width: fit-content!important;
#   height: fit-content!important;
#   position: initial!important;
# }
# .tip[data-v-6dedc520] {
#   display: none;
# }
# .modal-review ul[data-v-6dedc520] {
#   margin-top: 10px;
# }
# .modal-review .actions button[data-v-6dedc520] {
#   margin-top: 0;
# }
# .actions button[data-v-6dedc520] {
#   width: 100%;
#   border-radius: 19px;
# }
# .text-container[data-v-6dedc520] {
#   border: none!important;
# }
# textarea[data-v-6dedc520] {
#   border-radius: 12px!important;
# }
# input[type=text][data-v-6dedc520] {
#   border-radius: 18px!important;
# }
#   </style>
#   <style>
#    .overlay[data-v-00f85af6] {
#     background: rgba(0, 0, 0, 0.4);
#     position: fixed;
#     top: 0;
#     left: 0;
#     right: 0;
#     bottom: 0;
#     content: '';
#     z-index: 999;
#     display: block;
# }
# .modal-picture[data-v-00f85af6] {
#     position: fixed;
#     background: #fff;
#     z-index: 10000;
#     left: 50%;
#     top: 50%;
#     transform: translate(-50%, -50%);
#     box-sizing: border-box;
#     padding: 2px;
#     box-shadow: 0 3px 9px rgb(0 0 0 / 50%);
#     border: 1px solid #999;
# }
# .btn-close[data-v-00f85af6] {
#     font-size: 20px;
#     font-weight: bold;
#     border: none;
#     color: #fff;
#     position: absolute;
#     right: 10px;
#     top: 10px;
#     background: rgba(0,0,0,0.4);
#     border-radius: 50%;
#     width: 30px;
#     line-height: 30px;
# }
# .modal-picture img[data-v-00f85af6] {
#     max-width: 100%;
#     max-height: 90vh;
#     object-fit: contain;
#     margin: 0 auto;
# }
# @media screen and (max-width: 767px) {
# .modal-picture[data-v-00f85af6] {
#         box-sizing: border-box;
#         left: 20px;
#         right: 20px;
#         position: fixed;
#         width: unset;
#         transform: none;
#         max-height: 100vh;
#         text-align: center;
#         padding: 0;
#         transform: translateY(-50%);
# }
# .modal-picture img[data-v-00f85af6] {
#         max-height: 100%;
#         height: 100%;
#         width: 100%;
#         object-fit: contain;
#         box-sizing: border-box;
# }
# }
#   </style>
#   <style>
#   </style>
#   <style>
#    .overlay[data-v-647469c8] {
#     background: rgba(0, 0, 0, 0.4);
#     position: fixed;
#     top: 0;
#     left: 0;
#     right: 0;
#     bottom: 0;
#     content: '';
#     z-index: 999;
#     display: block;
# }
# .modal-video[data-v-647469c8] {
#     position: fixed;
#     background: #fff;
#     z-index: 10000;
#     left: 50%;
#     top: 50%;
#     transform: translate(-50%, -50%);
#     box-sizing: border-box;
#     padding: 2px;
#     box-shadow: 0 3px 9px rgb(0 0 0 / 50%);
#     border: 1px solid #999;
# }
# .btn-close[data-v-647469c8] {
#   z-index: 1;
#   font-size: 20px;
#   font-weight: bold;
#   border: none;
#   color: #fff;
#   position: absolute;
#   right: 10px;
#   top: 10px;
#   background: rgba(0,0,0,0.4);
#   border-radius: 50%;
#   width: 30px;
#   line-height: 30px;
# }
# .modal-video video[data-v-647469c8] {
#     max-width: 100%;
#     max-height: 90vh;
#     object-fit: contain;
#     margin: 0 auto;
# }
# @media screen and (max-width: 767px) {
# .modal-video[data-v-647469c8] {
#         box-sizing: border-box;
#         left: 20px;
#         right: 20px;
#         position: fixed;
#         width: unset;
#         transform: none;
#         max-height: 100vh;
#         text-align: center;
#         padding: 0;
#         transform: translateY(-50%);
# }
# .modal-video video[data-v-647469c8] {
#         max-height: 100%;
#         height: 100%;
#         width: 100%;
#         object-fit: contain;
#         box-sizing: border-box;
# }
# }
#   </style>
#   <style>
#    .mt-6[data-v-36bfc358] {
#   margin-top: 6px;
# }
# .mr-3[data-v-36bfc358] {
#   margin-right: 30px;
# }
# .starsV2[data-v-36bfc358] {
#   display: inline-block;
#   vertical-align: middle;
#   width: 105px;
#   min-width: fit-content;
# }
# .starsV2 .star[data-v-36bfc358] {
#   background: url(https://reviews.konfidency.com.br/americanas/38ec695ab29ee6d64d31.svg) no-repeat;
#   width: 21px;
#   height: 21px;
#   display: inline-block;
# }
# .starsV2 .star.fill[data-v-36bfc358] {
#   background: url(https://reviews.konfidency.com.br/americanas/6b75f8e9143eec83dfe9.svg) no-repeat;
# }
# .starsV2 .star.half[data-v-36bfc358] {
#   background: url(https://reviews.konfidency.com.br/americanas/edae0d4ee3cc092e09e6.svg) no-repeat;
# }
#   </style>
#   <style>
#    .starsV2 .star[data-v-36bfc358], .starsV2 .star.fill[data-v-36bfc358], .starsV2 .star.half[data-v-36bfc358] {
#   background-size: contain;
# }
#   </style>
#   <style>
#    #konfidency-reviews-container {
#   color: #3e3e3e;
#   max-width: 1300px;
#   margin: 0 auto;
#   padding: 20px;
#   box-sizing: border-box;
# }
#
# #konfidency-reviews-container.full {
#   max-width: unset;
#   margin: 0;
#   padding: 20px 0;
# }
#
# .konfidency-overlay #konfidency-reviews-container .reviews {
#   max-height: 500px;
#   overflow-y: auto;
# }
#
# .konfidency-overlay .konfidency-overlay-content {
#   color: #3e3e3e;
#   margin: 0 auto;
#   padding: 20px;
#   box-sizing: border-box;
#   position: absolute;
#   z-index: 100000;
#   background: #fff;
#   width: 50%;
#   left: 25%;
#   top: 10%;
#   border-radius: 10px;
# }
#
# #konfidency-reviews-container .content {
#   display: none;
# }
#
# #konfidency-reviews-container .content.loaded {
#   display: block;
# }
#
# .konfidency-overlay #konfidency-reviews-container {
#   padding: 0;
# }
#
# .konfidency-overlay #konfidency-reviews-container .summary {
#   display: none;
# }
#
# .konfidency-overlay #konfidency-reviews-container h2 {
#   display: none;
# }
#
# #konfidency-reviews-container .summary {
#   display: flex;
#   flex-direction: row;
#   justify-content: flex-end;
#   align-items: start;
# }
#
# #konfidency-reviews-container .summary .aggregate-rating {
#   font-size: 30px;
#   margin-right: 20px;
#   font-weight: bold;
# }
#
# #konfidency-reviews-container .summary .stars-container {
#   position: relative;
#   width: 104px;
#   height: 20px;
#   margin-top: 6px;
# }
#
# #konfidency-reviews-container .summary .stars-container .stars {
#   background: url(https://reviews.konfidency.com.br/americanas/6b75f8e9143eec83dfe9.svg) repeat-x left center;
#   position: absolute;
#   height: 20px;
#   top: 0;
#   left: 0;
# }
#
# #konfidency-reviews-container .summary .stars-container::before {
#   content: '';
#   background: url(https://reviews.konfidency.com.br/americanas/38ec695ab29ee6d64d31.svg) repeat-x left center;
#   position: absolute;
#   width: 104px;
#   height: 20px;
#   top: 0;
#   left: 0;
#   filter: grayscale(1);
# }
#
# #konfidency-reviews-container .summary .stars-count {
#   display: flex;
#   flex-direction: column;
# }
#
# #konfidency-reviews-container .summary .stars-count .review-count {
#   display: none;
# }
#
# #konfidency-reviews-container .summary .attribute-summary {
#   flex-grow: 1;
# }
#
# #konfidency-reviews-container .summary .attribute-summary .attributes {
#   width: 50%;
#   margin-left: auto;
#   margin-right: auto;
# }
#
# #konfidency-reviews-container
#   .summary
#   .attribute-summary
#   .attributes
#   .attribute {
#   display: flex;
#   flex-direction: row;
#   font-size: 15px;
#   align-items: center;
#   justify-content: space-between;
# }
#
# #konfidency-reviews-container
#   .summary
#   .attribute-summary
#   .attributes
#   .attribute
#   .name {
#   width: 35%;
#   font-weight: bold;
# }
#
# #konfidency-reviews-container
#   .summary
#   .attribute-summary
#   .attributes
#   .attribute
#   .attribute-rating {
#   width: 55%;
#   height: 8px;
#   border-radius: 4px;
#   background: #e8e8e8;
#   position: relative;
# }
#
# #konfidency-reviews-container .summary .attribute-summary .attributes .attribute .attribute-rating.stars {
#   width: 75%
# }
#
# #konfidency-reviews-container
#   .summary
#   .attribute-summary
#   .attributes
#   .attribute
#   .attribute-rating
#   .progress {
#   position: absolute;
#   z-index: 2;
#   background: var(--primary-color);
#   height: 8px;
#   border-radius: 4px;
# }
#
# #konfidency-reviews-container
#   .summary
#   .attribute-summary .attribute .rate:is(:has(+ .attribute-rating)) {
#     width: 15%!important;
#     text-align: left !important;
#   }
#
#   #konfidency-reviews-container
#   .summary
#   .attribute-summary .attribute .rate.multiple-choice {
#     width: 15%!important;
#   }
#
# #konfidency-reviews-container
#   .summary
#   .attribute-summary
#   .attributes
#   .attribute
#   .rate {
#   width: 15%;
#   text-align: right;
# }
#
# #konfidency-reviews-container .content .details .reviews .fetch-button {
#   display: flex;
#   justify-content: center;
#   padding-top: 20px;
#   padding-bottom: 20px;
# }
#
# #konfidency-reviews-container .content .details .reviews .fetch-button button {
#   border: 1px solid var(--primary-color);
#   color: var(--primary-color);
#   border-radius: 3px;
#   background-color: #fff;
#   padding: 10px 30px;
#   text-transform: uppercase;
#   cursor: pointer;
#   font-size: 14px;
# }
#
# #konfidency-reviews-container
#   .content
#   .details
#   .reviews
#   .fetch-button
#   button:disabled {
#   cursor: wait;
# }
#
# #konfidency-reviews-container
#   .content
#   .details
#   .reviews
#   .fetch-button
#   button
#   img {
#   vertical-align: top;
#   margin-left: 5px;
# }
#
# #konfidency-reviews-container .summary .review-button {
#   text-align: right;
# }
#
# #konfidency-reviews-container .summary .sort {
#   display: none;
# }
#
# #konfidency-reviews-container .review-button button {
#   border: 1px solid var(--primary-color);
#   color: var(--primary-color);
#   border-radius: 3px;
#   background-color: #fff;
#   padding: 10px 30px;
#   text-transform: uppercase;
#   cursor: pointer;
#   font-size: 14px;
# }
#
# #konfidency-reviews-container .summary .review-button button:disabled {
#   cursor: wait;
# }
#
# #konfidency-reviews-container .summary .review-button button img {
#   vertical-align: top;
#   margin-left: 5px;
# }
#
# #konfidency-reviews-container .details .no-reviews {
#   text-align: center;
# }
#
# #konfidency-reviews-container .details .no-reviews button {
#   display: block;
#   margin: 30px auto;
#   border-radius: 5px;
#   border: 1px solid var(--primary-color);
#   background: #fff;
#   padding: 10px 30px;
#   text-transform: uppercase;
#   font-size: 14px;
#   color: var(--primary-color);
# }
#
# .konfidency-overlay #konfidency-reviews-container .details .no-reviews button {
#   display: none;
# }
#
# #konfidency-reviews-container .details .details-header {
#   margin-top: 20px;
#   display: flex;
#   flex-direction: row;
#   justify-content: space-between;
# }
#
# #konfidency-reviews-container
#   .details
#   .details-header
#   .review-count
#   .aggregate-rating {
#   display: none;
# }
#
# #konfidency-reviews-container .details .details-header .review-count {
#   font-size: 22px;
#   font-weight: bold;
# }
#
# #konfidency-reviews-container .details .details-header .sort {
#   font-size: 12px;
# }
#
# #konfidency-reviews-container .details .details-header .sort .select-wrapper {
#   display: inline-block;
# }
#
# #konfidency-reviews-container .details .details-header .sort select {
#   padding: 5px 10px;
#   margin-left: 10px;
#   border: 1px solid #e8e8e8;
#   border-radius: 3px;
#   color: #3e3e3e;
#   text-transform: lowercase;
# }
#
# #konfidency-reviews-container .details .reviews .review {
#   display: flex;
#   flex-direction: row;
#   border-bottom: 1px solid #f3f3f3;
#   margin-top: 20px;
#   margin-bottom: 10px;
# }
#
# #konfidency-reviews-container .details .reviews .review:last-child {
#   border-bottom: none;
# }
#
# #konfidency-reviews-container .details .reviews .review-details {
#   display: flex;
#   flex-direction: row;
#   flex-wrap: wrap;
#   flex-grow: 1;
#   padding-bottom: 15px;
# }
#
# #konfidency-reviews-container .details .reviews .review-details .rating {
#   margin-right: 30px;
#   width: 83px;
#   height: 16px;
#   position: relative;
# }
#
# #konfidency-reviews-container
#   .details
#   .reviews
#   .review-details
#   .rating
#   .rating-text {
#   display: none;
# }
#
# #konfidency-reviews-container .details .reviews .review-details .rating .stars {
#   background: url(https://reviews.konfidency.com.br/americanas/6b75f8e9143eec83dfe9.svg) repeat-x left center;
#   position: absolute;
#   height: 16px;
#   top: 0;
#   left: 0;
# }
#
# #konfidency-reviews-container
#   .details
#   .reviews
#   .review-details
#   .rating::before {
#   content: '';
#   background: url(https://reviews.konfidency.com.br/americanas/38ec695ab29ee6d64d31.svg) repeat-x left center;
#   position: absolute;
#   width: 83px;
#   height: 16px;
#   top: 0;
#   left: 0;
#   filter: grayscale(1);
# }
#
# #konfidency-reviews-container .details .reviews .review-details .nameAndDate {
#   display: flex;
#   flex-direction: row;
#   flex: 1;
# }
#
# #konfidency-reviews-container .details .reviews .review-details .name {
#   margin-right: 30px;
#   font-size: 16px;
#   font-weight: 600;
#   max-width: 140px;
#   text-overflow: ellipsis;
#   white-space: nowrap;
#   overflow: hidden;
# }
#
# #konfidency-reviews-container .details .reviews .review-details .date {
#   margin-right: 30px;
#   font-size: 13px;
#   color: #787878;
# }
#
# #konfidency-reviews-container .details .reviews .review-details .verified {
#   font-size: 12px;
#   margin-left: 30px;
# }
#
# #konfidency-reviews-container
#   .details
#   .reviews
#   .review-details
#   .verified::before {
#   content: '';
#   width: 17px;
#   height: 17px;
#   background: url(https://reviews.konfidency.com.br/americanas/7f198d980bd8a677346a.png) no-repeat;
#   display: inline-block;
#   background-size: contain;
#   vertical-align: middle;
#   margin-right: 6px;
# }
#
# #konfidency-reviews-container .details .reviews .review-details .text {
#   width: 100%;
#   font-size: 16px;
#   margin-top: 15px;
# }
#
# #konfidency-reviews-container .details .reviews .review-details .review-files {
#   width: 100%;
#   margin-top: 15px;
#   display: inline-flex;
# }
#
# #konfidency-reviews-container .details .reviews .review-details .pictures img {
#   width: 80px;
#   height: 80px;
#   object-fit: cover;
#   margin-right: 10px;
#   margin-bottom: 8px;
#   border: 1px solid #ccc;
#   display: inline-block;
# }
#
# #konfidency-reviews-container .details .reviews .review-details .video {
#   display: inline-flex;
#   height: 80px;
#   width: 80px;
#   justify-content: center;
#   position: relative;
# }
# #konfidency-reviews-container .details .reviews .review-details .video video {
#   border: 1px solid #ccc;
#   background-color: black;
#   width: 80px;
#   height: 80px;
#   position: absolute;
# }
# #konfidency-reviews-container .details .reviews .review-details .video .player {
#   z-index: 1;
#   cursor: pointer;
#   background: none;
#   width: 50px;
#   height: 50px;
#   border: solid 5px #fff;
#   border-radius: 100%;
#   position: relative;
#   box-shadow: 2px 2px 5px black;
#   align-self: center;
# }
# #konfidency-reviews-container
#   .details
#   .reviews
#   .review-details
#   .video
#   .player
#   span {
#   width: 0;
#   height: 0;
#   border-top: 10px solid transparent;
#   border-left: 17px solid #fff;
#   border-bottom: 10px solid transparent;
#   position: absolute;
#   top: 50%;
#   left: 50%;
#   transform: translate(-50%, -50%);
# }
#
# #konfidency-reviews-container .details .reviews .review-details .attributes {
#   width: 100%;
#   font-size: 14px;
#   display: flex;
#   flex-direction: row;
#   flex-wrap: wrap;
# }
#
# #konfidency-reviews-container
#   .details
#   .reviews
#   .review-details
#   .attributes
#   .attribute {
#   margin-right: 40px;
#   width: 200px;
#   margin-top: 15px;
# }
#
# #konfidency-reviews-container
#   .details
#   .reviews
#   .review-details
#   .attributes
#   .attribute
#   label {
#   font-weight: bold;
#   display: flex;
#   width: 100%;
# }
#
# #konfidency-reviews-container
#   .details
#   .reviews
#   .review-details
#   .attributes
#   .attribute
#   label
#   span {
#   font-weight: normal;
#   width: 50%;
# }
#
# #konfidency-reviews-container
#   .details
#   .reviews
#   .review-details
#   .attributes
#   .attribute
#   label
#   span.title {
#     font-weight: bold;
#   }
#
# #konfidency-reviews-container
#   .details
#   .reviews
#   .review-details
#   .attributes
#   .attribute
# ...
#         display: flex;
#         flex: 1;
#     }
#
#     .dp-cookie-action .dp-switch {
#         width: 62px;
#     }
#
#     #dp-preferences-footer {
#         /* height: 60px; */
#         background-color: #E8E7E7;
#         display: flex;
#         vertical-align: middle;
#         font-size: 0.8em;
#     }
#
#     #dp-preferences-footer .developed-by {
#         width: 100%;
#         text-align: left;
#         padding: 18px;
#     }
#
#     #dp-preferences a {
#         text-decoration: none;
#         color: #26264A
#     }
#
#     #dp-preferences-footer .developed-by a {
#         font-weight: bold;
#     }
#
#     #dp-preferences-footer .policies {
#         text-align: left;
#         padding: 12px;
#         font-size: 1.2em;
#         font-family: "Courier new", sans-serif;
#         width:100%;
#     }
#
#     #dp-preferences-footer .policies a {
#         font-size: 0.8em;
#         font-family: Arial, Helvetica, sans-serif;
#     }
#
#     #dp-preferences-footer .save.accept-all button {
#         margin-right: 8px;
#     }
#
#     #dp-preferences-footer .save button {
#         border: none;
#         background-color: #2F98E9;
#         color: #fff;
#         padding: 8px 25px;
#         border-radius: 10px;
#         margin-top: 8px;
#         margin-right: 45px;
#         cursor: pointer;
#         font-size: 1rem !important;
#         word-break: normal;
#         min-width: max-content;
#     }
#
#     .dp-close-button {
#         width: 100%;
#     }
#
#     .dp-group-cookie-action .dp-switch {
#         width: 65px;
#         height: 25px;
#     }
#
#     .dp-group-cookie-action .dp-slider {
#         height: 30px;
#         max-width: 64px;
#         min-width: 64px;
#     }
#
#     .dp-group-cookie-action .dp-slider.round {
#         border-radius: 12px !important;
#     }
#
#     .dp-group-cookie-action .dp-slider.round:before {
#         height: 20px;
#         width: 20px;
#         margin-top: 3px;
#     }
#
#     .dp-switch {
#       position: relative;
#       display: inline-block;
#       width: 48px;
#       height: 21px;
#     }
#
#     /* Hide default HTML checkbox */
#     .dp-switch input {
#       opacity: 0;
#       width: 0;
#       height: 0;
#     }
#
#     .dp-slider-text {
#         padding-top: 2px;
#         text-align: right;
#         font-weight: bold;
#     }
#
#     /* The slider */
#     .dp-slider {
#       position: absolute;
#       cursor: pointer;
#       height: 21px;
#       top: 0;
#       left: 0;
#       right: 0;
#       bottom: 0;
#       background-color: #ccc;
#       -webkit-transition: .4s;
#       transition: .4s;
#       min-width: 48px;
#       max-width: 48px;
#     }
#
#     .dp-slider:before {
#       position: absolute;
#       content: "";
#       left: 1px;
#       background-color: white;
#       -webkit-transition: .4s;
#       transition: .4s;
#     }
#
#     input:checked + .dp-slider {
#       background-color: #2196F3;
#     }
#
#     input:focus + .dp-slider {
#       box-shadow: 0 0 1px #2196F3;
#     }
#
#     input:checked + .dp-slider-group:before {
#       -webkit-transform: translateX(38px) !important;
#       -ms-transform: translateX(38px) !important;
#       transform: translateX(38px) !important;
#       height: 22px !important;
#       width: 22px !important;
#       border: none;
#       bottom: 4px !important;
#     }
#
#     input:checked + .dp-slider:before {
#       -webkit-transform: translateX(27px);
#       -ms-transform: translateX(27px);
#       transform: translateX(27px);
#       height: 18px;
#       width: 18px;
#       border: none;
#       bottom: 2px;
#     }
#
#     /* Rounded sliders */
#     .dp-slider.round {
#       border-radius: 8px;
#     }
#
#     .dp-slider.round:before {
#       border-radius: 50%;
#       height: 18px;
#       width: 18px;
#       border-color: #26264A;
#       border-width: 2px;
#       border-style: solid;
#     }
#
#     .dp-tab-item-color-456 {
#        color: #26264a !important;
#     }
#     .dp-preferences-img-456 {
#        max-width: 100%;
#        max-height:100%;
#        width:auto;
#        height:auto;
#     }
#     .dp-topbar-close-container-svg-456{
#        width: 28px;
#     }
#    .dp-content-group-456 {
#       display:none;
#    }
#    .dp-content-group-456-important {
#       display: none !important;
#    }
#    .dp-preferences-footer-credit-456 {
#       position:absolute;
#       font-size: 8px;
#       margin:3px;
#    }
#    .dp-slider-text-456 {
#      width: 150px;
#    }
#    .dp-menu-456 {
#
#    }
#    .dp-save-456 {
#       margin-bottom: 1px;
#    }
#     /* ajustar tamanho e margem */#privacytools-banner-consent {max-width: 1248px !important;margin: 24px auto  !important;box-shadow: rgb(170, 170, 170) 0px 0px 10px;border-radius: 12px;} /* ajuste dos botões */.cc-foreground-btn-456 {    color: inherit;} .cc-btn {border: solid 1px !important;border-radius: 6px !important;font-weight: normal;} .cc-btn:hover {border: solid 1px transparent !important;} .cc-dismiss {color: #F80132 !important;border-color: #F80132;background: #ffffff00;} .cc-dismiss:hover {background-color: #F80132 !important;color: #fff !important;} .cc-deny {color: #666666 !important;border-color: #666666;background: #ffffff00;border: solid 1px  transparent !important;} .cc-deny:hover {background-color: transparent !important;text-decoration: underline;color: #666666;} .cc-message a {color: #F80132 !important;} /* config padrão */#dp-preferences-footer .save button {    border: none;    background-color: #F80132;    color: #fff;    padding: 8px 25px;    border-radius: 6px;    margin-top: 8px;    margin-right: 45px;    cursor: pointer;    font-size: 1rem !important;    word-break: normal;    min-width: max-content;} input:checked + .dp-slider {    background-color: #F80132;} #dp-preferences a {    text-decoration: none;    color: #F80132;} #dp-preferences {    position: fixed;    margin-left: calc(50vw - 400px);    margin-top: calc(50vh - 310px);    min-width: 500px;    max-width: 800px;    max-height: 600px;    color: #666666 !important;    font-family: Arial, Roboto, sans-serif;    font-size: 14px;    background-color: #FFFFFF;    box-shadow: rgb(170, 170, 170) 0px 0px 10px;    border-radius: 12px;    box-sizing: initial !important;    -webkit-box-sizing: border-box;    box-sizing: border-box;    -webkit-font-smoothing: antialiased;} /* ajuste popup privacidade */.dp-tab-item-color-456 {background: none;} .dp-selected-menu {background: #F80132 !important;color: #F80132 !important;} #dp-preferences-footer {padding: 12px 0px !important;border-radius: 0px 0px 12px 12px !important;background: #f1f1f1 !important;} .dp-preferences-topbar {border-bottom: none !important;} .dp-group-cookie-action .dp-slider.round {border-radius: 64px !important;} @media screen and (max-width: 648px) {     #privacytools-banner-consent {        width: 100%  !important;        margin: 0 auto  !important;        box-shadow: rgb(170, 170, 170) 0px 0px 10px  !important;        border-radius: 12px 12px 0px 0px  !important;   }     .dp-bar-description {        margin-top: 10px !important;        margin-bottom: 24px !important;    }     .dp-bar-preference {        width: 100% !important;        display: block !important;        text-align: center !important;        margin-top: 24px !important;    }     #dp-preferences {        margin-left: 5%;        margin-top: 5%;        min-width: 90%;        max-width: 90%;        max-height: 90%;    }     .dp-menu-item {        background-color: #f1f1f1;        color: #666 !important;        padding: 6px 0px;    }     .dp-selected-menu {        background: #F80132 !important;        color: #fff !important;    }      .dp-save button {        background: #F80132 !important;        color: #fff;        border: none;        border-radius: 6px;        width: 85%;        margin: 12px auto !important;        padding: 12px;        box-sizing: border-box;    }     #dp-preferences-footer {        text-align: center;     }     #dp-preferences-footer .developed-by {        width: 100%;        line-height: 20px;        text-align: left;    }     #dp-preferences-footer .developed-by {        text-align: left;    }     .dp-save button {        height: 20px;    }} @media screen and (max-width: 1366px) and (min-width: 649px) { #privacytools-banner-consent {margin: 64px auto  !important;} #dp_content_obj2 .cc-window.cc-floating {max-width: 95% !important;box-sizing: border-box;left: 2.5%;padding: 1em !important;} .dp-bar-preference {margin-right: -20px;} .cc-message {font-size: 14px !important;line-height: 1.5em;} }
#    </style>
#    <div id="dp_content_obj2" title="Privacy Tools - Cookie Management">
#     <span class="dp-cookie-policy-button-desc cc-revoke dp-add-listener" id="revokedp-desc12435" onclick="javascript:window.cookieconsent.privacyToolsShowCookieNotice();" rel="noopener nofollow" style="display: none;">
#      <img alt="Logotipo do Banner de Gerenciamento de Cookies" class="cc-revoke-btn-img-456" onclick="this.parentElement.click(); return false;" src="https://cdn.privacytools.com.br/assets/1d301fe8-a68f-48ae-8ded-c3ba158b17fe/banner/B01949C33CF64E767665FBE3DB9A3372.png"/>
#     </span>
#     <div aria-describedby="cookieconsent:desc" aria-label="cookieconsent" aria-live="polite" author="Privacy Tools" class="cc-window cc-banner cc-type-info cc-theme-block cc-bottom cc-color-override-1394182910 cc-message-none-456" id="privacytools-banner-consent" role="dialog" style="">
#      <!--googleoff: all-->
#      <span aria-label="dismiss cookie message" class="cc-close dp-add-listener cc-foreground-btn-456" onclick="javascript:clsBnnerPref();" tabindex="0">
#       ×
#      </span>
#      <div class="privacy-tools-layout">
#       <div class="dp-bar-description">
#        <span class="cc-message cc-element-message-color-456" id="cookieconsent:desc" style="color: rgb(102, 102, 102);">
#         <strong>
#          Americanas e os cookies:
#         </strong>
#         a gente usa cookies para personalizar anúncios e melhorar a sua experiência no site. Ao continuar navegando, você concorda com o nosso
#         <a href="https://www.americanas.com.br/especial/aviso-de-privacidade" style="color: rgb(102, 102, 102);" target="_blank">
#          Aviso de Privacidade
#         </a>
#         .
#        </span>
#        <span aria-label="dismiss cookie message" class="cc-close cc-foreground-btn-456" id="dm876B" tabindex="0">
#         ×
#        </span>
#       </div>
#       <div class="dp-bar-actions">
#        <div class="cc-compliance">
#         <span aria-label="" class="cc-btn cc-deny dp-add-listener cc-dny-btn-456" href="javascript:void(0)" onclick="doNotSell();return false;" rel="noopener nofollow" tabindex="0">
#          <div class="dp-bar-button cc-foreground-btn-456" title="">
#          </div>
#         </span>
#        </div>
#        <span aria-label="Aceitar" class="cc-btn cc-dismiss dp-add-listener" id="dm876A" onclick="enableAllCookies();return false;" rel="noopener nofollow" tabindex="0">
#         <div class="dp-bar-button dp-bar-dismiss cc-foreground-btn-456" title="Aceitar">
#          Aceitar
#         </div>
#        </span>
#        <div class="dp-bar-preference">
#         <span aria-label="Preferências" class="cc-link dp-add-listener cc-element-message-color-456" onclick="javascript:overlayT2345Preference();return false;" rel="noopener nofollow" style="color: rgb(102, 102, 102);" tabindex="0" title="Preferências">
#          Preferências
#         </span>
#        </div>
#       </div>
#      </div>
#      <!--googleon: all-->
#     </div>
#    </div>
#    <div id="dp_content_preference" title="Privacy Tools - Cookie Management - https://www.privacytools.com.br">
#    </div>
#   </div>
#   <script async="" class="ins-camp-frameless-js ins-camp-frameless-js-451" classname="ins-camp-frameless-js ins-camp-frameless-js-451" type="text/javascript">
#    try {(function(camp){var smartRecommender;var templateConfig={campaign:camp};var templateInit=function(){templateConfig.selectors={contentWrapper:'.ins-content-wrapper-'+camp.id,previewWrapper:'.ins-preview-wrapper-'+camp.id,body:'.ins-web-smart-recommender-body',recommendedItems:'[data-recommended-items]',boxItem:'.ins-web-smart-recommender-box-item',productBox:'.ins-product-box.ins-element-link.ins-add-to-cart-wrapper.ins-sr-api',productId:'[ins-product-id]',eventCollection:'[event-collection]',addToCart:'.ins-add-to-cart-wrapper'};templateConfig.settings={};Insider.dom(templateConfig.selectors.contentWrapper).closest(templateConfig.selectors.previewWrapper).remove();smartRecommender=new Insider.campaign.smartRecommender;var endpoint=smartRecommender.getRecommendationUrl(templateConfig);if(!endpoint){return false}try{Insider.request.get({url:endpoint,success:function(response){var payload={campaignId:Insider.campaign.getBuilderIdByVariationId(camp.id),variationId:camp.id,products:response.data};Insider.eventManager.dispatch('ins-sr:only-api-campaign:load',payload);Insider.fns.onElementLoaded(templateConfig.selectors.previewWrapper,function(){templateConfig.apiBasedData=response.data;smartRecommender.init(templateConfig)},{type:'interval'}).listen();if(payload.products.length<templateConfig.campaign.predictiveFeedSettings.minFeedSize){Insider.fns.onElementLoaded(templateConfig.selectors.previewWrapper,function(){Insider.dom(templateConfig.selectors.previewWrapper).hide()},{type:'interval'}).listen()}else{var addToCartSelector=templateConfig.selectors.previewWrapper+' '+templateConfig.selectors.boxItem+' '+templateConfig.selectors.addToCart;Insider.fns.onElementLoaded(addToCartSelector,function(){var productsWithKey=Insider.fns.keyBy(payload.products,'item_id');Insider.dom(addToCartSelector).accessNodes(function(element){var productId=element.getAttribute('ins-product-id');element.setAttribute('ins-product-data',Insider.fns.stringify(productsWithKey[productId][0]))})},{type:'interval'}).listen()}Insider.logger.log(JSON.stringify(payload))}.bind(this),parse:true})}catch(exception){Insider.errorBag.add(exception);Insider.dom(templateConfig.selectors.previewWrapper).hide()}return true};var prepareTemplate=function(){if(Insider.fns.isUndefined(Insider.campaign.smartRecommender)){try{Insider.request.script({charset:'UTF-8',src:Insider.__external.EITRI_URL+'ins-smart-recommender.js',success:templateInit})}catch(exception){Insider.errorBag.add(exception)}}else{templateInit()}};prepareTemplate();Insider.eventManager.on('framelessInited'+camp.id,prepareTemplate);})({"id":451,"predictiveFeedSettings":{"pId":10011749,"feedSize":20,"minFeedSize":1,"feedSource":"mostBoughtOfCat","filters":[],"manualProducts":[],"generateMixedStrategy":false,"hyperParameter":false,"mixedProducts":[],"shuffleResults":false,"excludeCartProducts":false,"excludeRecentlyViewed":false,"excludeViewDuration":7,"excludeViewItem":"","excludeViewDurationType":"0","excludeViewOption":"0","excludeRecentlyPurchased":false,"excludePurchaseDuration":7,"excludePurchaseItem":"","excludePurchaseDurationType":"0","excludePurchaseOption":"0","campaignType":"smart-recommender-api-based","checkoutRecommendationCartValue":0},"locationConfig":{"type":2,"mode":"adaptive","position":"fixed","left":651.6666870117188,"top":270,"windowHeight":540,"windowWidth":2053,"windowHref":"","selectedElement":"body","insertAction":"before","frameless":true,"gridIsActive":false},"currencyFormatRules":{"BRL":{"name":"Brazilian Real","symbol":"R$","alignment":"0","thousandSeparator":".","decimalSeparator":",","decimalCount":2,"value":"BRL"}},"strategyId":7063,"smsConfig":{"virtualLongNumber":""}});}catch(err){Insider.errorBag.add(err);}
#   </script>
#   <script src="/_next/static/chunks/2078-96f42a5a33a361e6.js">
#   </script>
#   <script src="/_next/static/chunks/1882-f8979c8e8337f47c.js">
#   </script>
#   <script src="/_next/static/chunks/pages/%5Bslug%5D/p-0c680da99cf6acb8.js">
#   </script>
#   <iframe allow="join-ad-interest-group *; run-ad-auction *; shared-storage *" aria-hidden="true" browsingtopics="" height="0" hidden="" src="https://fledge.us.criteo.com/interest-group?data=7BQ0WJa8nTFcsLrgC_5jHunBUAbCntVtvBArKxB9azKPDLOD5-qBpFaVCAo-tis2Ox4wflnF-RvADJtcxWVy0lzXwAmAn2Udj0HpQfKw4MGiu3bcA-1hN7dgCHPZLAKcUOA6mGKAO7nKutBnVkoN8Rlzaaa6wlxeqkiDQPToGaOVBrGKNsUnZR6tTS7ofGUt" title="Criteo Fledge iframe" width="0">
#   </iframe>
#   <iframe aria-hidden="true" height="0" hidden="" title="Criteo DIS iframe" width="0">
#   </iframe>
#  </body>
# </html>

# %%
name_list = []
price_list = []

for item in soup.find_all('h3', attrs={'class': 'ProductCard_productName__mwx7Y'}):
    name_list.append(item.text)

for item in soup.find_all('p', attrs={'class': 'ProductCard_productPrice__XFEqu'}):
    price_list.append(item.text)    
    
merged_dict = dict(zip(name_list, price_list))

df = pd.DataFrame(list(merged_dict.items()), columns=['Produto', 'Preço'])

df['Preço'] = df['Preço'].apply(clean_price)

df['Fornecedor'] = 'Americanas'
df['Data'] = pd.to_datetime('today').normalize()

# %%
display(df)
# Out:
#                                               Produto     Preço  Fornecedor  \
# 0       Apple iPhone 16 Pro Max 256GB Titânio Natural  11369.00  Americanas
# 1                   Apple iPhone 16 128GB Ultramarino   6279.00  Americanas
# 2       Apple iPhone 16 Pro Max 512GB Titânio natural  12749.00  Americanas
# 3        Apple iPhone 16 Pro Max 256GB Titânio branco  11369.00  Americanas
# 4   IPhone 16 Pro Max Apple (256GB) Titânio Desert...  11597.42  Americanas
# 5              Apple iPhone 16 Plus 128GB Ultramarino   8719.00  Americanas
# 6   IPhone 16 Apple (128GB) Rosa, Tela de 6,1, 5G ...   6583.92  Americanas
# 7   IPhone 16 Pro Max Apple (256GB) Titânio Preto,...  11568.44  Americanas
# 8       Apple iPhone 16 Pro Max 256GB Titânio Deserto  11369.00  Americanas
# 9        Apple iPhone 16 Pro Max 512GB Titânio branco  12749.00  Americanas
# 10        Apple iPhone 16 Pro Max 512GB Titânio preto  12749.00  Americanas
# 11             Apple iPhone 16 Plus 256GB Ultramarino   9359.00  Americanas
# 12        Apple iPhone 16 Pro Max 256GB Titânio preto  11369.00  Americanas
# 13                   Apple iPhone 16 Plus 128GB Preto   8719.00  Americanas
# 14  IPhone 16 Apple (128GB) Preto, Tela de 6,1, 5G...   6584.03  Americanas
# 15          Apple iPhone 16 Pro 128GB Titânio Deserto   9569.00  Americanas
# 16                    Apple iPhone 16 Plus 128GB Rosa  10258.92  Americanas
# 17            Apple iPhone 16 Pro 256GB Titânio Preto  10309.00  Americanas
# 18       Usado: iPhone 11 128GB Preto Bom - Trocafone   1781.10  Americanas
# 19  iPhone 13 Apple 128GB iOS 5G Wi-Fi Tela 6.1'' ...   5149.00  Americanas
# 20       Usado: iPhone 12 128GB Preto Bom - Trocafone   2285.10  Americanas
# 21  Usado: iPhone 12 64GB Preto Muito Bom - Trocafone   2123.10  Americanas
# 22  iPhone 13 Apple 128GB iOS 5G Wi-Fi Tela 6.1'' ...   4259.00  Americanas
# 23  Apple iPhone 14 128GB iOS 5G Wi-Fi Tela 6.1" C...   5146.94  Americanas
# 24                        Caixa de Bombom Garoto 250g     13.99  Americanas
# 25          Chocolate Kit Kat ao Leite Nestlé - 41,5g      3.99  Americanas
# 26            Caixa Bombom Especialidades Nestlé 251g     14.99  Americanas
# 27  Barra de Chocolate Branco Lacta com Recheio Ou...      7.99  Americanas
# 28            Barra de Chocolate Alpino  Nestlé - 85g      7.99  Americanas
# 29  Barra de Chocolate ao Leite Lacta com Recheio ...      7.99  Americanas
# 30              Barra de Chocolate Lacta ao Leite 80g      7.99  Americanas
# 31     Barra de Chocolate ao Leite Diamante Negro 80g      7.99  Americanas
# 32            Barra de Chocolate Branco Laka Oreo 80g      7.99  Americanas
# 33                 Barra de Chocolate Branco Laka 80g      7.99  Americanas
# 34  Ovo de Páscoa Playstation Chocolate ao Leite 9...     64.99  Americanas
# 35  Ovo de Páscoa Manchester City Chocolate ao Lei...    159.99  Americanas
# 36  Ovo de Páscoa LOL OMG Chocolate ao Leite 80g -...     25.99  Americanas
# 37  Ovo de Páscoa Chocolate ao Leite Bluey 80g - T...     25.99  Americanas
# 38  Ovo de Páscoa Ben 10 Chocolate ao Leite 80g - ...     25.99  Americanas
# 39  Ovo de Páscoa LOL Chocolate ao Leite 90g - Delice     64.99  Americanas
# 40  Ovo de Páscoa Flamengo Chocolate ao Leite Topc...    159.99  Americanas
# 41  Ovo de Páscoa Chocolate ao Leite Ben 10 90g - ...     64.99  Americanas
# 42  Ovo de Páscoa Crocante Chocolate ao Leite 120g...     32.99  Americanas
# 43  Ovo de Páscoa Bluey Chocolate ao Leite 90g - T...     64.99  Americanas
# 44                       Chocolate Bis Lacta Xtra 45g      3.99  Americanas
# 45  Barra de Chocolate ao Leite com Caramelo Doura...     18.99  Americanas
# 46                      Bis Chocolate ao Leite 100,8g      7.99  Americanas
# 47  Mucilon Meu Primeiro Lanchinho Nestlé Sabor Mi...      6.51  Americanas
# 48    Composto lácteo neslac comfor zero lactose 700G     72.99  Americanas
# 49           Mucilon snack morango E banan 35G nestle      5.49  Americanas
# 50                Biscoito Oreo Recheado Baunilha 36g      2.79  Americanas
# 51                     Chocolate Bis Lacta 100,8 Laka      7.49  Americanas
# 52  Mochaccino em Cápsula Dolce Gusto Canela Nesca...     29.99  Americanas
# 53           Biscoito Recheado Mini Oreo Original 35g      3.49  Americanas
#
#          Data
# 0  2025-05-19
# 1  2025-05-19
# 2  2025-05-19
# 3  2025-05-19
# 4  2025-05-19
# 5  2025-05-19
# 6  2025-05-19
# 7  2025-05-19
# 8  2025-05-19
# 9  2025-05-19
# 10 2025-05-19
# 11 2025-05-19
# 12 2025-05-19
# 13 2025-05-19
# 14 2025-05-19
# 15 2025-05-19
# 16 2025-05-19
# 17 2025-05-19
# 18 2025-05-19
# 19 2025-05-19
# 20 2025-05-19
# 21 2025-05-19
# 22 2025-05-19
# 23 2025-05-19
# 24 2025-05-19
# 25 2025-05-19
# 26 2025-05-19
# 27 2025-05-19
# 28 2025-05-19
# 29 2025-05-19
# 30 2025-05-19
# 31 2025-05-19
# 32 2025-05-19
# 33 2025-05-19
# 34 2025-05-19
# 35 2025-05-19
# 36 2025-05-19
# 37 2025-05-19
# 38 2025-05-19
# 39 2025-05-19
# 40 2025-05-19
# 41 2025-05-19
# 42 2025-05-19
# 43 2025-05-19
# 44 2025-05-19
# 45 2025-05-19
# 46 2025-05-19
# 47 2025-05-19
# 48 2025-05-19
# 49 2025-05-19
# 50 2025-05-19
# 51 2025-05-19
# 52 2025-05-19
# 53 2025-05-19

# %%
nome = 'iphone_16_' + df['Data'].dt.date.iloc[0].strftime('%Y-%m-%d') + '_' + df['Fornecedor'].iloc[0] + '.csv'
df.to_csv(nome, index=False, encoding='utf-8-sig')
